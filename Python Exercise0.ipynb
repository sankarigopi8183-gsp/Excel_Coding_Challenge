# %% [markdown]
# <a href="https://colab.research.google.com/github/sankarigopi8183-gsp/Excel_Coding_Challenge/blob/main/Python%20Exercise0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('hi')
# Out:
# hi

# %%
a=8
type (a)
# Out:
# int

# %%
N='Padhu'
A=18
FS='English'
print ('My Name is:',N)
print ('My Age is:',A)
print ('My Favorite Subject is:', FS)
# Out:
# My Name is: Padhu
# My Age is: 18
# My Favorite Subject is: English

# %%
n=input('Enter Your Name:' )
a=input('Enter Your Age:')
fs=input('Enter Your Favorite Subject:')
# Out:
# Enter Your Name:Sai
# Enter Your Age:5
# Enter Your Favorite Subject:Maths

# %%
#STRING
text= '!Hello Python Level!'
print(type(text))

text[-6]
# Out:
# <class 'str'>
# 'L'

# %%
#STRING SLICING

text[6:-1]
# Out:
# 'Python Level'

# %%
text[::-1]
# Out:
# '!leveL nohtyP olleH!'
